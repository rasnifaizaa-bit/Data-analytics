# %% [markdown]
# # python programming

# %% [markdown]
# ## variables

# %%
a=10

# %%
print(a)
# Out:
# 10

# %%
b=20

# %%
print(b)
# Out:
# 20

# %%
c=a+b

# %%
c
# Out:
# 30

# %%
name=("rasni")
place=("ponnani")
age=(20)

# %%
name
# Out:
# 'rasni'

# %%
print("my name is",name,"iam from",place,"iam",age,"years old")
# Out:
# my name is rasni iam from ponnani iam 20 years old

# %% [markdown]
# ## data types

# %% [markdown]
# 1. intiger
# 2. floating point numbers
# 3. string
# 4. boolean

# %%
type(a)
# Out:
# int

# %%
type(2.5)
# Out:
# float

# %%
type(name)
# Out:
# str

# %%
type("orange")
# Out:
# str

# %%
t=True

# %%
type(t)
# Out:
# bool

# %%
m=False

# %%
type(m)
# Out:
# bool

# %%
type(place)
# Out:
# str

# %%
s="8136904602"

# %%
type(s)
# Out:
# str

# %%
type(b)
# Out:
# int

# %%
type(c)
# Out:
# int

# %%
x="faiza"

# %%
type(x)
# Out:
# str

# %% [markdown]
# ## list

# %%
list1=[1,2,3,4,5]

# %%
type(list1)
# Out:
# list

# %%
details=[1,"rasni faiza","ponnani",3.4,True]

# %%
list1.append(100)

# %%
list1
# Out:
# [1, 2, 3, 4, 5, 100]

# %%
list1.append("afisa")

# %%
list1
# Out:
# [1, 2, 3, 4, 5, 100, 'afisa']

# %%
list1.extend([10,20,30])

# %%
list1
# Out:
# [1, 2, 3, 4, 5, 100, 'afisa', 10, 20, 30]

# %%
list1.append([100,200])

# %%
list1
# Out:
# [1, 2, 3, 4, 5, 100, 'afisa', 10, 20, 30, [100, 200]]

# %%
list1
# Out:
# [1, 2, 3, 4, 5, 100, 'afisa', 10, 20, 30, [100, 200]]

# %%
len(list1)
# Out:
# 11

# %%
list1[-1]
# Out:
# [100, 200]

# %%
list1[5]
# Out:
# 100

# %%
list1.insert(3,"faiza")

# %%
list1
# Out:
# [1, 2, 3, 'faiza', 4, 5, 100, 'afisa', 10, 20, 30, [100, 200]]

# %%
list2=[10,20,30,40,50]

# %%
list2.sort()

# %%
list2
# Out:
# [10, 20, 30, 40, 50]

# %%
list2.sort(reverse=True)

# %%
list2
# Out:
# [50, 40, 30, 20, 10]

# %%
list2.reverse()

# %%
list2
# Out:
# [10, 20, 30, 40, 50]

# %%
list2.pop()
# Out:
# 50

# %%
list2.pop(3)
# Out:
# 40

# %%
abc=list2.pop()

# %%
list2
# Out:
# [10, 20]

# %%
abc
# Out:
# 30

# %%
list2.index(20)
# Out:
# 1

# %%
list1.index(3)
# Out:
# 2

# %%
list2.count(20)
# Out:
# 1

# %%
list2.copy()
# Out:
# [10, 20]

# %%
list1.remove(2)

# %%
list1
# Out:
# [1, 3, 'faiza', 4, 5, 100, 'afisa', 10, 20, 30, [100, 200]]

# %%
list2.remove(10)

# %%
list2
# Out:
# [20]

# %%
list3=[500,1000,2000]

# %%
list3
# Out:
# [500, 1000, 2000]

# %%
list3.insert(2,"shamsi")

# %%
list3
# Out:
# [500, 1000, 'shamsi', 2000]

# %%
list3.insert(4,"hadi")

# %%
list3
# Out:
# [500, 1000, 'shamsi', 2000, 'hadi']

# %% [markdown]
# list3.copy()

# %%
list3.pop()
# Out:
# 'hadi'

# %%
list3.index(500)
# Out:
# 0

# %%
abc=list3.pop()

# %%
list3
# Out:
# [500, 1000, 'shamsi']

# %%
list3.pop(1)
# Out:
# 1000

# %%
list3
# Out:
# [500, 'shamsi']

# %% [markdown]
# # comparison operator

# %% [markdown]
# ## logical operators
# 1. and
# 2. or
# 3. not

# %%
p=True
q=False
r=True

# %%
print(p and r)
# Out:
# True

# %%
print(q and p)
# Out:
# False

# %%
print(p or q)
# Out:
# True

# %%
print(not q)
# Out:
# True

# %%
print(not p)
# Out:
# False

# %%
print(not r)
# Out:
# False

# %% [markdown]
# # membership operators,identity operators

# %%
print(list1)
# Out:
# [1, 3, 'faiza', 4, 5, 100, 'afisa', 10, 20, 30, [100, 200]]

# %%
print(100 in list1)
# Out:
# True

# %%
print(88 in list1)
# Out:
# False

# %%
print(100 not in list1)
# Out:
# False

# %%
print(88 not in list1)
# Out:
# True

# %%
f=10

# %%
a=10

# %%
print(a is f)
# Out:
# True

# %%
print(a is not f)
# Out:
# False

# %% [markdown]
# # assingment operators

# %%
b=40

# %%
b+=2 #b=b+2

# %%
print(b)
# Out:
# 42

# %%
b-=2 #b=b-2

# %%
print(b)
# Out:
# 40

# %%
b/=2 #b=b/2

# %%
print(b)
# Out:
# 20.0

# %%
b*=2 #b=b*2

# %%
print(b)
# Out:
# 40.0

# %%
name="rasni"
place="ponnani"
age=20

# %%
print(f"my name is {name},iam from {place},iam {age} years old")
# Out:
# my name is rasni,iam from ponnani,iam 20 years old

# %%
print("details")
print("-"*8)
print(f"my name is {name},iam from {place},iam {age} years old")
# Out:
# details
# --------
# my name is rasni,iam from ponnani,iam 20 years old

# %%
print("""rasni
ponnani
data analytics""")
# Out:
# rasni
# ponnani
# data analytics

# %% [markdown]
# # tuple

# %%
t1=(1,2,3)

# %%
t1[0]
# Out:
# 1

# %%
list1
# Out:
# [1, 3, 'faiza', 4, 5, 100, 'afisa', 10, 20, 30, [100, 200]]

# %%
list1[0]
# Out:
# 1

# %%
list1[0]=2

# %%
list1
# Out:
# [2, 3, 'faiza', 4, 5, 100, 'afisa', 10, 20, 30, [100, 200]]

# %%
t1[0]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[548], line 1
# ----> 1 t1[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1.count(2)

# %%
t1.index(2)

# %% [markdown]
# # set

# %%
set1={1,2,3,4,5,6,7,8}

# %%
set1

# %%
type(set1)

# %%
set2={2,3,4}

# %%
set1.add(14)

# %%
set1

# %%
set1.add(10)

# %%
set1

# %%
set1.difference(set2)

# %%
set1.intersection(set2)

# %%
set1.union(set2)

# %%
set1.issubset(set2)

# %%
set2.issubset(set1)

# %%
set1.issuperset(set2)

# %%
set2.issuperset(set1)

# %%
set1.isdisjoint(set2)

# %%
set2.isdisjoint(set1)

# %%
set3={21,22,23,24}

# %%
set3

# %%
set1.isdisjoint(set3)

# %%
set3.isdisjoint(set1)

# %% [markdown]
# # dictionary

# %%
dict1={"name":"rasni","place":"ponnani","age":20.0}

# %%
dict1
# Out:
# {'name': 'rasni', 'place': 'ponnani', 'age': 20.0}

# %%
len(dict1)
# Out:
# 3

# %%
dict2={"name":["afisa","farsana","saida"],"place":["amayam","tirur","edappal"],"age":[21,19,20]}

# %%
dict2
# Out:
# {'name': ['afisa', 'farsana', 'saida'],
#  'place': ['amayam', 'tirur', 'edappal'],
#  'age': [21, 19, 20]}

# %%
dict1.get("name")
# Out:
# 'rasni'

# %%
dict2.get("name")
# Out:
# ['afisa', 'farsana', 'saida']

# %%
dict2.items()
# Out:
# dict_items([('name', ['afisa', 'farsana', 'saida']), ('place', ['amayam', 'tirur', 'edappal']), ('age', [21, 19, 20])])

# %%
dict2.keys()
# Out:
# dict_keys(['name', 'place', 'age'])

# %%
dict2["age"]
# Out:
# [21, 19, 20]

# %%
dict2.values()
# Out:
# dict_values([['afisa', 'farsana', 'saida'], ['amayam', 'tirur', 'edappal'], [21, 19, 20]])

# %%
dict2.copy()
# Out:
# {'name': ['afisa', 'farsana', 'saida'],
#  'place': ['amayam', 'tirur', 'edappal'],
#  'age': [21, 19, 20]}

# %%
dict2.update()

# %%
dict2
# Out:
# {'name': ['afisa', 'farsana', 'saida'],
#  'place': ['amayam', 'tirur', 'edappal'],
#  'age': [21, 19, 20]}

# %%
dict2["name"]
# Out:
# ['afisa', 'farsana', 'saida']

# %%
dict2["name"][0]
# Out:
# 'afisa'

# %%
dict2["name"][1]
# Out:
# 'farsana'

# %%
dict2["name"][2]
# Out:
# 'saida'

# %%
dict2["name"][1]="jazmin"

# %%
dict2
# Out:
# {'name': ['afisa', 'jazmin', 'saida'],
#  'place': ['amayam', 'tirur', 'edappal'],
#  'age': [21, 19, 20]}

# %%
dict2["name"][2]="thesni"

# %%
dict2
# Out:
# {'name': ['afisa', 'jazmin', 'thesni'],
#  'place': ['amayam', 'tirur', 'edappal'],
#  'age': [21, 19, 20]}

# %%
dict2["name"][0]="musthafa"

# %%
dict2
# Out:
# {'name': ['musthafa', 'jazmin', 'thesni'],
#  'place': ['amayam', 'tirur', 'edappal'],
#  'age': [21, 19, 20]}

# %%
dict2["age"][0]=22

# %%
dict2
# Out:
# {'name': ['musthafa', 'jazmin', 'thesni'],
#  'place': ['amayam', 'tirur', 'edappal'],
#  'age': [22, 19, 20]}

# %%
dict2["age"][1]=20

# %%
dict2
# Out:
# {'name': ['musthafa', 'jazmin', 'thesni'],
#  'place': ['amayam', 'tirur', 'edappal'],
#  'age': [22, 20, 20]}

# %%
dict2["age"][2]=21

# %%
dict2
# Out:
# {'name': ['musthafa', 'jazmin', 'thesni'],
#  'place': ['amayam', 'tirur', 'edappal'],
#  'age': [22, 20, 21]}

# %%
class1={"batch":{"students":["styles","salman","shahinsha"],"scores":[100,99,98]},
        "batch2":{"students":["ashik","nabeel","shahid"],"scores":[60,80,70]}}

# %%
class1["batch"]
# Out:
# {'students': ['styles', 'salman', 'shahinsha'], 'scores': [100, 99, 98]}

# %%
class1["batch2"]
# Out:
# {'students': ['ashik', 'nabeel', 'shahid'], 'scores': [60, 80, 70]}

# %%
class1["batch"]["students"]
# Out:
# ['styles', 'salman', 'shahinsha']

# %%
class1["batch2"]["students"][0]
# Out:
# 'ashik'

# %%
class1["batch"]["students"][0]="adhil"

# %%
class1
# Out:
# {'batch': {'students': ['adhil', 'salman', 'shahinsha'],
#   'scores': [100, 99, 98]},
#  'batch2': {'students': ['ashik', 'nabeel', 'shahid'], 'scores': [60, 80, 70]}}

# %%
class1["batch2"]["students"][0]="arif"

# %%
class1
# Out:
# {'batch': {'students': ['adhil', 'salman', 'shahinsha'],
#   'scores': [100, 99, 98]},
#  'batch2': {'students': ['arif', 'nabeel', 'shahid'], 'scores': [60, 80, 70]}}
