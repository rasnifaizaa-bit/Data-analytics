# %% [markdown]
# # Q1

# %%
import pandas as pd

# %%
pd.read_csv(r"C:\Users\HP\Downloads\netflix_titles.csv.zip")
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix=pd.read_csv(r"C:\Users\HP\Downloads\netflix_titles.csv.zip")

# %%
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Q2

# %%
netflix.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %% [markdown]
# # Q3

# %%
netflix.shape
# Out:
# (8807, 12)

# %% [markdown]
# # Q4

# %%
netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
netflix.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# # Q5

# %%
netflix.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# # Q6

# %%
netflix["rating"].nunique()
# Out:
# 17

# %% [markdown]
# # Q7

# %%
netflix[netflix["type"]=="Movie"]
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %% [markdown]
# # Q8

# %%
netflix[netflix["country"]=="India"]
# Out:
#      show_id     type                          title                 director  \
# 4         s5  TV Show                   Kota Factory                      NaN
# 24       s25    Movie                          Jeans               S. Shankar
# 39       s40  TV Show                   Chhota Bheem                      NaN
# 50       s51  TV Show                  Dharmakshetra                      NaN
# 66       s67  TV Show  Raja Rasoi Aur Anya Kahaniyan                      NaN
# ...      ...      ...                            ...                      ...
# 8773   s8774    Movie            Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show                Yeh Meri Family                      NaN
# 8798   s8799    Movie                       Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                          Zenda           Avadhoot Gupte
# 8806   s8807    Movie                         Zubaan              Mozez Singh
#
# ...

# %% [markdown]
# # Q9

# %%
netflix[netflix["release_year"]>2015]
# Out:
#      show_id     type                      title         director  \
# 0         s1    Movie       Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show              Blood & Water              NaN
# 2         s3  TV Show                  Ganglands  Julien Leclercq
# 3         s4  TV Show      Jailbirds New Orleans              NaN
# 4         s5  TV Show               Kota Factory              NaN
# ...      ...      ...                        ...              ...
# 8787   s8788    Movie  You Can’t Fight Christmas      Kenny Young
# 8794   s8795    Movie                     اشتباك     Mohamed Diab
# 8796   s8797  TV Show                 Yunus Emre              NaN
# 8797   s8798  TV Show                  Zak Storm              NaN
# 8803   s8804  TV Show                Zombie Dumb              NaN
#
#                                                    cast  \
# 0                                                   NaN
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %% [markdown]
# # Q10

# %%
netflix[netflix["title"].str.contains("Love")]
# Out:
#      show_id     type                           title  \
# 25       s26  TV Show            Love on the Spectrum
# 158     s159    Movie         Love Don't Cost a Thing
# 159     s160    Movie                  Love in a Puff
# 206     s207    Movie       LSD: Love, Sex Aur Dhokha
# 227     s228    Movie                     Really Love
# ...      ...      ...                             ...
# 8567   s8568  TV Show  The Year of Happiness and Love
# 8575   s8576  TV Show                 This Is My Love
# 8649   s8650    Movie           Two Lovers and a Bear
# 8721   s8722  TV Show                   What Is Love?
# 8725   s8726    Movie            What's Up With Love?
#
#                        director  \
# 25                          NaN
# 158                   Troy Byer
# 159              Pang Ho-cheung
# 206            Dibakar Banerjee
# 227       Angel Kristi Williams
# ...                         ...
# 8567                        NaN
# 8575                        NaN
# ...

# %% [markdown]
# # Q11

# %%
netflix[netflix["duration"]>"90 min"]
# Out:
#      show_id   type                             title  \
# 6         s7  Movie  My Little Pony: A New Generation
# 13       s14  Movie  Confessions of an Invisible Girl
# 18       s19  Movie                         Intrusion
# 28       s29  Movie                        Dark Skies
# 38       s39  Movie               Birth of the Dragon
# ...      ...    ...                               ...
# 8774   s8775  Movie                         يوم الدين
# 8781   s8782  Movie           Yo-Kai Watch: The Movie
# 8791   s8792  Movie                       Young Adult
# 8794   s8795  Movie                            اشتباك
# 8801   s8802  Movie                           Zinzana
#
#                            director  \
# 6     Robert Cullen, José Luis Ucha
# 13                    Bruno Garotti
# 18                       Adam Salky
# 28                    Scott Stewart
# 38                     George Nolfi
# ...                             ...
# 8774                Abu Bakr Shawky
# ...

# %% [markdown]
# # Q12

# %%
netflix.dropna(subset=["director"])
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...                             ...
# ...

# %% [markdown]
# # Q13

# %%
netflix["country"].fillna("unknown")
# Out:
# 0       United States
# 1        South Africa
# 2             unknown
# 3             unknown
# 4               India
#             ...
# 8802    United States
# 8803          unknown
# 8804    United States
# 8805    United States
# 8806            India
# Name: country, Length: 8807, dtype: object

# %% [markdown]
# # Q14

# %%
netflix["cast"].isnull().sum()
# Out:
# np.int64(825)

# %% [markdown]
# # Q15

# %%
netflix["rating"]=netflix["rating"].fillna("Not Rated")

# %%
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
netflix["rating"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Q16

# %%
netflix["date_added"]=pd.to_datetime(netflix["date_added"].str.strip(),format="%B %d, %Y")

# %%
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Q17

# %%
netflix["year_added"]=netflix["date_added"].dt.year

# %%
netflix["year_added"]
# Out:
# 0       2021.0
# 1       2021.0
# 2       2021.0
# 3       2021.0
# 4       2021.0
#          ...
# 8802    2019.0
# 8803    2019.0
# 8804    2019.0
# 8805    2020.0
# 8806    2019.0
# Name: year_added, Length: 8807, dtype: float64

# %% [markdown]
# # Q18

# %%
netflix["month_added"]=netflix["date_added"].dt.month_name()

# %%
netflix["month_added"]
# Out:
# 0       September
# 1       September
# 2       September
# 3       September
# 4       September
#           ...
# 8802     November
# 8803         July
# 8804     November
# 8805      January
# 8806        March
# Name: month_added, Length: 8807, dtype: object

# %% [markdown]
#  # Q19

# %%
netflix[netflix["year_added"]==2020].shape[0]
# Out:
# 1879

# %% [markdown]
# # Q20

# %%
netflix["month_added"].value_counts().head(1)
# Out:
# month_added
# July    827
# Name: count, dtype: int64

# %% [markdown]
# # Q21

# %%
netflix["release_year"].value_counts()
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: count, Length: 74, dtype: int64

# %% [markdown]
# # Q22

# %%
netflix.groupby("type").size()
# Out:
# type
# Movie      6131
# TV Show    2676
# dtype: int64

# %% [markdown]
# # Q23

# %%
netflix["release_year"].mean()
# Out:
# np.float64(2014.1801975701146)

# %% [markdown]
# # Q24

# %%
netflix["country"].value_counts().head(3)
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Name: count, dtype: int64

# %% [markdown]
# # Q25

# %%
netflix[netflix["type"]=="TV Show"].groupby("release_year").size()
# Out:
# release_year
# 1925      1
# 1945      1
# 1946      1
# 1963      1
# 1967      1
# 1972      1
# 1974      1
# 1977      1
# 1979      1
# 1981      1
# 1985      1
# 1986      2
# 1988      2
# 1989      1
# 1990      3
# 1991      1
# 1992      3
# 1993      4
# 1994      2
# 1995      2
# 1996      3
# 1997      4
# 1998      4
# 1999      7
# 2000      4
# 2001      5
# 2002      7
# 2003     10
# 2004      9
# 2005     13
# 2006     14
# 2007     14
# 2008     23
# 2009     34
# 2010     40
# 2011     40
# 2012     64
# 2013     63
# 2014     88
# 2015    162
# 2016    244
# 2017    265
# 2018    380
# 2019    397
# 2020    436
# 2021    315
# dtype: int64

# %% [markdown]
# # Q26

# %%
netflix[netflix["title"].str.contains("Martin")]
# Out:
#      show_id   type                                              title  \
# 3424   s3425  Movie        Martin Matte: La vie, la mort...eh la la..!
# 3646   s3647  Movie                    Demetri Martin: The Overthinker
# 3759   s3760  Movie  Rolling Thunder Revue: A Bob Dylan Story by Ma...
# 3832   s3833  Movie                                        Dry Martina
# 4851   s4852  Movie  Steve Martin and Martin Short: An Evening You ...
# 5899   s5900  Movie                 Demetri Martin: Live (At the Time)
# 6902   s6903  Movie       Guy Martin: Last Flight of the Vulcan Bomber
# 7411   s7412  Movie                    Martin Lawrence Live: Runteldat
# 7412   s7413  Movie     Martin Luther: The Idea that Changed the World
#
#                        director  \
# 3424        Jean-François Blais
# 3646  Jay Karas, Demetri Martin
# 3759            Martin Scorsese
# 3832               Che Sandoval
# 4851               Marcus Raboy
# 5899                  Jay Karas
# ...

# %% [markdown]
# # Q27

# %%
netflix["cast"].str.split(",").str[0]
# Out:
# 0                   NaN
# 1            Ama Qamata
# 2         Sami Bouajila
# 3                   NaN
# 4            Mayur More
#              ...
# 8802       Mark Ruffalo
# 8803                NaN
# 8804    Jesse Eisenberg
# 8805          Tim Allen
# 8806      Vicky Kaushal
# Name: cast, Length: 8807, dtype: object

# %% [markdown]
# # Q28

# %%
netflix["listed_in"].str.contains("Comedy").sum()
# Out:
# np.int64(399)

# %% [markdown]
# # Q29

# %%
netflix["title_length"]=netflix["title"].str.len()

# %%
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Q30

# %%
netflix["listed_in"]=netflix["listed_in"].str.lower()

# %%
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Q31

# %%
netflix.sort_values("release_year",ascending=False)
# Out:
#      show_id     type                                          title  \
# 693     s694    Movie                         Ali & Ratu Ratu Queens
# 781     s782    Movie          Black Holes | The Edge of All We Know
# 762     s763    Movie                                   Sweet & Sour
# 763     s764  TV Show                                    Sweet Tooth
# 764     s765    Movie                   Trippin' with the Kandasamys
# ...      ...      ...                                            ...
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8763   s8764    Movie                WWII: Report from the Aleutians
# 8205   s8206    Movie                           The Battle of Midway
# 7790   s7791    Movie                                 Prelude to War
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
#
#             director                                               cast  \
# ...

# %% [markdown]
# # Q32

# %%
netflix[netflix["release_year"]==netflix["release_year"].min()]
# Out:
#      show_id     type                              title director cast  \
# 4250   s4251  TV Show  Pioneers: First Women Filmmakers*      NaN  NaN
#
#      country date_added  release_year rating  duration listed_in  \
# 4250     NaN 2018-12-30          1925  TV-14  1 Season  tv shows
#
#                                             description  year_added  \
# 4250  This collection restores films from women who ...      2018.0
#
#      month_added  title_length
# 4250    December            33

# %%
netflix[netflix["release_year"]==netflix["release_year"].max()]
# Out:
#      show_id     type                      title         director  \
# 1         s2  TV Show              Blood & Water              NaN
# 2         s3  TV Show                  Ganglands  Julien Leclercq
# 3         s4  TV Show      Jailbirds New Orleans              NaN
# 4         s5  TV Show               Kota Factory              NaN
# 5         s6  TV Show              Midnight Mass    Mike Flanagan
# ...      ...      ...                        ...              ...
# 1468   s1469    Movie  What Happened to Mr. Cha?     Kim Dong-kyu
# 1551   s1552  TV Show                      Hilda              NaN
# 1696   s1697  TV Show               Polly Pocket              NaN
# 2920   s2921  TV Show              Love Is Blind              NaN
# 8437   s8438  TV Show     The Netflix Afterparty              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %% [markdown]
# # Q33

# %%
netflix.sort_values("title").head(5)
# Out:
#      show_id   type                          title  \
# 2036   s2037  Movie                         #Alive
# 2304   s2305  Movie  #AnneFrank - Parallel Stories
# 2481   s2482  Movie              #FriendButMarried
# 2324   s2325  Movie            #FriendButMarried 2
# 5973   s5974  Movie                          #Roxy
#
#                          director  \
# 2036                       Cho Il
# 2304  Sabina Fedeli, Anna Migotto
# 2481                Rako Prijanto
# 2324                Rako Prijanto
# 5973              Michael Kennedy
#
#                                                    cast      country  \
# 2036                           Yoo Ah-in, Park Shin-hye  South Korea
# 2304                        Helen Mirren, Gengher Gatti        Italy
# 2481  Adipati Dolken, Vanesha Prescilla, Rendi Jhon,...    Indonesia
# 2324  Adipati Dolken, Mawar de Jongh, Sari Nila, Von...    Indonesia
# 5973  Jake Short, Sarah Fisher, Booboo Stewart, Dann...       Canada
#
# ...

# %% [markdown]
# # Q34

# %%
netflix.set_index("show_id",inplace=True)

# %%
netflix
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# ...          ...                    ...              ...
# s8803      Movie                 Zodiac    David Fincher
# s8804    TV Show            Zombie Dumb              NaN
# s8805      Movie             Zombieland  Ruben Fleischer
# s8806      Movie                   Zoom     Peter Hewitt
# s8807      Movie                 Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Q35

# %%
netflix.reset_index(inplace=True)

# %%
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Q36

# %%
netflix["content_age"]=2024-netflix["release_year"]

# %%
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Q37

# %%
netflix["is_movie"]=netflix["type"]=="Movie"

# %%
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Q38

# %%
netflix["duration_int"]=netflix["duration"].str.split().str[0]

# %%
netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Q39

# %%
netflix.groupby(["rating","type"]).size()
# Out:
# rating     type
# 66 min     Movie         1
# 74 min     Movie         1
# 84 min     Movie         1
# G          Movie        41
# NC-17      Movie         3
# NR         Movie        75
#            TV Show       5
# Not Rated  Movie         2
#            TV Show       2
# PG         Movie       287
# PG-13      Movie       490
# R          Movie       797
#            TV Show       2
# TV-14      Movie      1427
#            TV Show     733
# TV-G       Movie       126
#            TV Show      94
# TV-MA      Movie      2062
#            TV Show    1145
# TV-PG      Movie       540
#            TV Show     323
# TV-Y       Movie       131
#            TV Show     176
# TV-Y7      Movie       139
#            TV Show     195
# TV-Y7-FV   Movie         5
#            TV Show       1
# UR         Movie         3
# dtype: int64

# %% [markdown]
# # Q42

# %%
netflix[(netflix["director"]=="Christopher Nolan")&(netflix["country"]=="United States, United Kingdom")]
# Out:
#     show_id   type      title           director  \
# 340    s341  Movie  Inception  Christopher Nolan
#
#                                                   cast  \
# 340  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
#
#                            country date_added  release_year rating duration  \
# 340  United States, United Kingdom 2021-08-01          2010  PG-13      148
#
#                                            listed_in  \
# 340  action & adventure, sci-fi & fantasy, thrillers
#
#                                            description  year_added  \
# 340  A troubled thief who extracts secrets from peo...      2021.0
#
#     month_added  title_length  content_age  is_movie duration_int
# 340      August             9           14      True          148

# %% [markdown]
# # Q43

# %%
netflix[(netflix["listed_in"].str.contains("Drama|Thriller"))&(netflix["release_year"]==2021)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, year_added, month_added, title_length, content_age, is_movie, duration_int]
# Index: []

# %% [markdown]
# # Q44

# %%
netflix["title"].str.contains("Tom Hanks").sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Q45

# %%
netflix["listed_in"].str.split(",")
# Out:
# 0                                         [documentaries]
# 1       [international tv shows,  tv dramas,  tv myste...
# 2       [crime tv shows,  international tv shows,  tv ...
# 3                               [docuseries,  reality tv]
# 4       [international tv shows,  romantic tv shows,  ...
#                               ...
# 8802                   [cult movies,  dramas,  thrillers]
# 8803           [kids' tv,  korean tv shows,  tv comedies]
# 8804                           [comedies,  horror movies]
# 8805                [children & family movies,  comedies]
# 8806    [dramas,  international movies,  music & music...
# Name: listed_in, Length: 8807, dtype: object

# %%
netflix["listed_in"].str.split(",").explode().value_counts().head(1)
# Out:
# listed_in
# international movies    2624
# Name: count, dtype: int64

# %% [markdown]
# # Q46

# %%
netflix.groupby(["rating","type"])["title"].count()
# Out:
# rating     type
# 66 min     Movie         1
# 74 min     Movie         1
# 84 min     Movie         1
# G          Movie        41
# NC-17      Movie         3
# NR         Movie        75
#            TV Show       5
# Not Rated  Movie         2
#            TV Show       2
# PG         Movie       287
# PG-13      Movie       490
# R          Movie       797
#            TV Show       2
# TV-14      Movie      1427
#            TV Show     733
# TV-G       Movie       126
#            TV Show      94
# TV-MA      Movie      2062
#            TV Show    1145
# TV-PG      Movie       540
#            TV Show     323
# TV-Y       Movie       131
#            TV Show     176
# TV-Y7      Movie       139
#            TV Show     195
# TV-Y7-FV   Movie         5
#            TV Show       1
# UR         Movie         3
# Name: title, dtype: int64

# %% [markdown]
# # Q47

# %%
netflix[(netflix["month_added"]=="January")&(netflix["release_year"]<2010)]
# Out:
#      show_id   type                    title          director  \
# 1422   s1423  Movie                 Apaharan       Prakash Jha
# 1423   s1424  Movie             BluffMaster!       Rohan Sippy
# 1426   s1427  Movie                Gangaajal       Prakash Jha
# 1441   s1442  Movie            Hello Brother       Sohail Khan
# 1447   s1448  Movie                  Case 39  Christian Alvart
# ...      ...    ...                      ...               ...
# 8764   s8765  Movie               Wyatt Earp   Lawrence Kasdan
# 8766   s8767  Movie                      XXx         Rob Cohen
# 8767   s8768  Movie  XXX: State of the Union      Lee Tamahori
# 8773   s8774  Movie      Yanda Kartavya Aahe      Kedar Shinde
# 8805   s8806  Movie                     Zoom      Peter Hewitt
#
#                                                    cast  \
# 1422  Ajay Devgn, Nana Patekar, Bipasha Basu, Ayub K...
# 1423  Abhishek Bachchan, Priyanka Chopra, Riteish De...
# ...

# %% [markdown]
# # Q48

# %% [markdown]
# # Q49

# %%
netflix["director"].value_counts().head(5)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Name: count, dtype: int64

# %% [markdown]
# # Q50
